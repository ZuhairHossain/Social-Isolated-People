# %%
from google.colab import drive 

drive.mount('/content/drive')
# %cd drive/MyDrive/Datasets/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Datasets

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Dataset_original.csv')
df
# Out:
#           ID  Residence  Sex  Age  Age_Group  Job_Group  Health_Worker_Self  \
# 0          1          2    1   65          1          4                   2
# 1          2          7    1   55          2          1                   2
# 2          3          3    1   60          2          1                   2
# 3          4          5    1   57          2          1                   2
# 4          5          7    1   53          2          1                   2
# ...      ...        ...  ...  ...        ...        ...                 ...
# 11328  11329          7    1   37          3          5                   2
# 11329  11330          3    2   41          2          1                   2
# 11330  11331          3    1   52          2          1                   2
# 11331  11332          1    2   27          3          1                   2
# 11332  11333          1    2   18          4          3                   2
#
# ...

# %%
df.head()
# Out:
#    ID  Residence  Sex  Age  Age_Group  Job_Group  Health_Worker_Self  \
# 0   1          2    1   65          1          4                   2
# 1   2          7    1   55          2          1                   2
# 2   3          3    1   60          2          1                   2
# 3   4          5    1   57          2          1                   2
# 4   5          7    1   53          2          1                   2
#
#    Health_Worker_Family  Married  Income  ...  Preventive_Behaviors  Optimism  \
# 0                     2        2     2.0  ...                     7         4
# 1                     2        2     4.0  ...                     4         4
# 2                     2        2     3.0  ...                     7         2
# 3                     1        2     4.0  ...                     7         4
# 4                     1        2     4.0  ...                     5         4
#
#    Deterioration_Economy  Deterioration_Interact  Frustration  Covid_Anxiety  \
# ...

# %%
df.describe().T
# Out:
#                           count         mean          std   min     25%  \
# ID                      11333.0  5667.000000  3271.699635   1.0  2834.0
# Residence               11333.0     3.431219     2.011036   1.0     2.0
# Sex                     11333.0     1.524310     0.499431   1.0     1.0
# Age                     11333.0    46.249801    14.550446  18.0    35.0
# Age_Group               11333.0     2.230301     0.673283   1.0     2.0
# Job_Group               11333.0     1.643431     1.120443   1.0     1.0
# Health_Worker_Self      11333.0     1.941675     0.234368   1.0     2.0
# Health_Worker_Family    11333.0     1.912556     0.282497   1.0     2.0
# Married                 11333.0     1.621459     0.485045   1.0     1.0
# Income                   9626.0     4.330355     2.663295   1.0     2.0
# Current_Physical        11333.0     1.957469     0.201805   1.0     2.0
# Past_Physical           11333.0     1.924910     0.263549   1.0     2.0
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print("Keys of Heath Dataset:\n", df.keys())
# Out:
# Keys of Heath Dataset:
#  Index(['ID', 'Residence', 'Sex', 'Age', 'Age_Group', 'Job_Group',
#        'Health_Worker_Self', 'Health_Worker_Family', 'Married', 'Income',
#        'Current_Physical', 'Past_Physical', 'Current_Mental', 'Past_Mental',
#        'K6', 'PHQ9', 'UCLA_LS3', 'LSNS6', 'Exercise', 'Healthy_Diet',
#        'Healthy_Sleep', 'Activity', 'Interaction_Offline',
#        'Interaction_Online', 'Preventive_Behaviors', 'Optimism',
#        'Deterioration_Economy', 'Deterioration_Interact', 'Frustration',
#        'Covid_Anxiety', 'Covid_Sleepless', 'Difficulty_Living',
#        'Difficulty_Work', 'depressed'],
#       dtype='object')

# %%
print("Lubben Social Network Scale–6:\n", df['LSNS6'])
# Out:
# Lubben Social Network Scale–6:
#  0         2
# 1        15
# 2         6
# 3         9
# 4         3
#          ..
# 11328     8
# 11329     3
# 11330    12
# 11331    13
# 11332     7
# Name: LSNS6, Length: 11333, dtype: int64

# %%
print("Type of data:", type(df['LSNS6']))
# Out:
# Type of data: <class 'pandas.core.series.Series'>

# %%
print("Shape of target:", df.shape)
# Out:
# Shape of target: (11333, 34)

# %%
conditions = [(df['LSNS6']<12),(df['LSNS6']>=12)]

choices = [0,1]

df['lsns6_loneliness'] = np.select(conditions, choices, default=0)
print(df[['LSNS6', 'lsns6_loneliness']])
# Out:
#        LSNS6  lsns6_loneliness
# 0          2                 0
# 1         15                 1
# 2          6                 0
# 3          9                 0
# 4          3                 0
# ...      ...               ...
# 11328      8                 0
# 11329      3                 0
# 11330     12                 1
# 11331     13                 1
# 11332      7                 0
#
# [11333 rows x 2 columns]

# %%
print(df['lsns6_loneliness'].value_counts())
# Out:
# 0    6337
# 1    4996
# Name: lsns6_loneliness, dtype: int64

# %%
from sklearn.model_selection import train_test_split
df.drop(labels='Income', axis=1)

#random data splitting
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=1)
# Out:
#           ID  Residence  Sex  Age  Age_Group  Job_Group  Health_Worker_Self  \
# 0          1          2    1   65          1          4                   2
# 1          2          7    1   55          2          1                   2
# 2          3          3    1   60          2          1                   2
# 3          4          5    1   57          2          1                   2
# 4          5          7    1   53          2          1                   2
# ...      ...        ...  ...  ...        ...        ...                 ...
# 11328  11329          7    1   37          3          5                   2
# 11329  11330          3    2   41          2          1                   2
# 11330  11331          3    1   52          2          1                   2
# 11331  11332          1    2   27          3          1                   2
# 11332  11333          1    2   18          4          3                   2
#
# ...

# %%
numerics = [cname for cname in df.columns if df[cname].dtype in ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']]
y_train = df.lsns6_loneliness
X_train = df[numerics].copy()

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (11333, 35)
# y_train shape: (11333,)

# %%
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e0dfc9ceb537> in <module>()
# ----> 1 print("X_test shape:", X_test.shape)
#       2 print("y_test shape:", y_test.shape)
#
# NameError: name 'X_test' is not defined

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train,y_train)
predict = classifier.predict(X_test)
accuracy_score(y_test,predict)
