# %%
from google.colab import drive 

drive.mount('/content/drive')
# %cd drive/MyDrive/Datasets/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Datasets

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Dataset_original.csv')

# %%
df
# Out:
#           ID  Residence  Sex  ...  Difficulty_Living  Difficulty_Work  depressed
# 0          1          2    1  ...                  4                4          1
# 1          2          7    1  ...                  4                3          0
# 2          3          3    1  ...                  4                7          0
# 3          4          5    1  ...                  1                1          0
# 4          5          7    1  ...                  5                5          0
# ...      ...        ...  ...  ...                ...              ...        ...
# 11328  11329          7    1  ...                  1                1          0
# 11329  11330          3    2  ...                  3                6          1
# 11330  11331          3    1  ...                  6                7          0
# 11331  11332          1    2  ...                  4                4          0
# 11332  11333          1    2  ...                  5                4          0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11333 entries, 0 to 11332
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      11333 non-null  int64
#  1   Residence               11333 non-null  int64
#  2   Sex                     11333 non-null  int64
#  3   Age                     11333 non-null  int64
#  4   Age_Group               11333 non-null  int64
#  5   Job_Group               11333 non-null  int64
#  6   Health_Worker_Self      11333 non-null  int64
#  7   Health_Worker_Family    11333 non-null  int64
#  8   Married                 11333 non-null  int64
#  9   Income                  9626 non-null   float64
#  10  Current_Physical        11333 non-null  int64
#  11  Past_Physical           11333 non-null  int64
#  12  Current_Mental          11333 non-null  int64
#  13  Past_Mental             11333 non-null  int64
# ...

# %%
df.hist(figsize=(20,15))
plt.show()

# %%
sns.countplot(df['K6'])
# psychological distress
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['PHQ9'])
# depression
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['UCLA_LS3'])
# loneliness
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['LSNS6'])
#Lubben Social Network Scale
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Notes

# https://pubmed.ncbi.nlm.nih.gov/33122626/

# %%
  #condition testing
  print(df['PHQ9']>10)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11328    False
# 11329     True
# 11330    False
# 11331    False
# 11332    False
# Name: PHQ9, Length: 11333, dtype: bool

# %%
conditions = [(df['PHQ9']<10),(df['PHQ9']>=10)]

choices = [0,1]

df['depressed'] = np.select(conditions, choices, default=0)

#show all columns, uncomment this line
# pd.set_option('display.max_rows', df.shape[0]+1)
print(df[['PHQ9', 'depressed']])
# Out:
#        PHQ9  depressed
# 0        10          1
# 1         6          0
# 2         5          0
# 3         5          0
# 4         8          0
# ...     ...        ...
# 11328     2          0
# 11329    11          1
# 11330     7          0
# 11331     5          0
# 11332     1          0
#
# [11333 rows x 2 columns]

# %%
print(df['depressed'].value_counts())
# Out:
# 0    9299
# 1    2034
# Name: depressed, dtype: int64

# %%
sns.countplot(df['depressed'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#df.to_csv('Dataset_original.csv', index=False)
